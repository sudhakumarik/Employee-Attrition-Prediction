# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Import statements required for Plotly
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import SelectKBest, chi2,f_classif
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import roc_curve, roc_auc_score
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# reading the data
train_data = pd.read_csv('/content/drive/MyDrive/Datasets/Emp_attrition_Train.csv')

# %%
#dataset overview
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028 entries, 0 to 1027
# Data columns (total 31 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Ename                                           1028 non-null   object
#  1   Age                                             1028 non-null   int64
#  2   NumCompaniesWorked                              1028 non-null   int64
#  3   Previous company experience                     1028 non-null   object
#  4   Job role in previous company                    1028 non-null   object
#  5   Number of years experience in prevoius company  1028 non-null   int64
#  6   Reason for leaving                              1028 non-null   object
#  7   Salary in previous company                      1028 non-null   float64
#  8   Present expectation Y/N                         1028 non-null   object
#  9   Expectation of hike in %                        1028 non-null   float64
#  10  Promotion Y/N                                   1028 non-null   object
#  11  New designation after promotion                 1028 non-null   object
#  12  Attrition                                       1028 non-null   object
#  13  BusinessTravel                                  1028 non-null   object
#  14  Department                                      1028 non-null   object
#  15  Education                                       1028 non-null   int64
#  16  EmployeeNumber                                  1028 non-null   int64
#  17  EnvironmentSatisfaction                         1028 non-null   int64
#  18  Gender                                          1028 non-null   object
#  19  JobInvolvement                                  1028 non-null   int64
#  20  JobLevel                                        1028 non-null   int64
#  21  JobRole                                         1028 non-null   object
#  22  JobSatisfaction                                 1028 non-null   int64
#  23  MaritalStatus                                   1028 non-null   object
#  24  MonthlyIncome                                   1028 non-null   int64
#  25  OverTime                                        1028 non-null   object
#  26  PerformanceRating                               1028 non-null   int64
#  27  StockOptionLevel                                1028 non-null   int64
#  28  TotalWorkingYears                               1028 non-null   int64
#  29  YearsAtCompany                                  1028 non-null   int64
#  30  YearsWithCurrManager                            1028 non-null   int64
# dtypes: float64(2), int64(15), object(14)
# memory usage: 249.1+ KB

# %%
train_data.drop(['Ename','EmployeeNumber'],axis=1,inplace=True)

# %%
#statistical view of dataset
train_data.describe()
# Out:
#                Age  NumCompaniesWorked  \
# count  1028.000000         1028.000000
# mean     36.999027            2.218872
# std       9.444297            1.251972
# min      18.000000            0.000000
# 25%      30.000000            1.000000
# 50%      36.000000            2.000000
# 75%      43.000000            3.000000
# max      60.000000            4.000000
#
#        Number of years experience in prevoius company  \
# count                                     1028.000000
# mean                                         2.697471
# std                                          2.527534
# min                                          0.000000
# 25%                                          1.000000
# 50%                                          2.000000
# 75%                                          4.000000
# max                                          9.000000
#
#        Salary in previous company  Expectation of hike in %    Education  \
# count                 1028.000000               1028.000000  1028.000000
# mean                  3316.286965                  0.148784     2.873541
# std                   2427.873920                  0.166618     1.032840
# min                    504.500000                  0.000000     1.000000
# 25%                   1443.000000                  0.000000     2.000000
# 50%                   2453.750000                  0.150000     3.000000
# 75%                   4364.750000                  0.350000     4.000000
# max                   9999.500000                  0.500000     5.000000
#
#        EnvironmentSatisfaction  JobInvolvement     JobLevel  JobSatisfaction  \
# count              1028.000000     1028.000000  1028.000000      1028.000000
# mean                  2.719844        2.731518     2.093385         2.757782
# std                   1.089614        0.703240     1.141854         1.105306
# min                   1.000000        1.000000     1.000000         1.000000
# 25%                   2.000000        2.000000     1.000000         2.000000
# 50%                   3.000000        3.000000     2.000000         3.000000
# 75%                   4.000000        3.000000     3.000000         4.000000
# max                   4.000000        4.000000     5.000000         4.000000
#
#        MonthlyIncome  PerformanceRating  StockOptionLevel  TotalWorkingYears  \
# count    1028.000000        1028.000000       1028.000000        1028.000000
# mean     6632.573930           3.152724          0.758755          11.417315
# std      4855.747841           0.359896          0.836236           8.015441
# min      1009.000000           3.000000          0.000000           0.000000
# 25%      2886.000000           3.000000          0.000000           6.000000
# 50%      4907.500000           3.000000          1.000000          10.000000
# 75%      8729.500000           3.000000          1.000000          16.000000
# max     19999.000000           4.000000          3.000000          40.000000
#
#        YearsAtCompany  YearsWithCurrManager
# count     1028.000000           1028.000000
# mean         7.250973              4.141051
# std          6.203562              3.608460
# min          1.000000              0.000000
# 25%          3.000000              2.000000
# 50%          5.000000              3.000000
# 75%          9.000000              7.000000
# max         40.000000             17.000000

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

numeric_df = train_data.select_dtypes(include=numerics)
numeric_df.columns
# Out:
# Index(['Age', 'NumCompaniesWorked',
#        'Number of years experience in prevoius company',
#        'Salary in previous company', 'Expectation of hike in %', 'Education',
#        'EnvironmentSatisfaction', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIncome', 'PerformanceRating',
#        'StockOptionLevel', 'TotalWorkingYears', 'YearsAtCompany',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
train_data.select_dtypes(include='object').columns.unique()
# Out:
# Index(['Previous company experience', 'Job role in previous company',
#        'Reason for leaving', 'Present expectation Y/N', 'Promotion Y/N',
#        'New designation after promotion', 'Attrition', 'BusinessTravel',
#        'Department', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime'],
#       dtype='object')

# %%
category_df = train_data.select_dtypes(include='object')
category_df
# Out:
#      Previous company experience Job role in previous company  \
# 0                            Yes       Junior Sales Executive
# 1                            Yes           Research Scientist
# 2                            Yes        Laboratory Technician
# 3                            Yes           Research Scientist
# 4                            Yes        Laboratory Technician
# ...                          ...                          ...
# 1023                         Yes           Research Scientist
# 1024                         Yes            Research Director
# 1025                          No       Junior Sales Executive
# 1026                         Yes       Junior Sales Executive
# 1027                         Yes        Laboratory Technician
#
#                                      Reason for leaving  \
# 0                         Lack of flexible work options
# 1                                      for a higher pay
# 2                         Lack of flexible work options
# 3                         Lack of flexible work options
# 4                         Lack of flexible work options
# ...                                                 ...
# 1023                      Lack of flexible work options
# 1024  Lack of opportunities for carrier growth and d...
# 1025                             No previous experience
# 1026                      Lack of flexible work options
# 1027                      Lack of flexible work options
#
#      Present expectation Y/N Promotion Y/N New designation after promotion  \
# 0                        Yes           Yes                 Sales Executive
# 1                        Yes           Yes              Research Scientist
# 2                        Yes           Yes           Laboratory Technician
# 3                        Yes           Yes              Research Scientist
# 4                        Yes           Yes           Laboratory Technician
# ...                      ...           ...                             ...
# 1023                     Yes           Yes              Research Scientist
# 1024                     Yes           Yes               Research Director
# 1025                     Yes           Yes                 Sales Executive
# 1026                     Yes           Yes                 Sales Executive
# 1027                     Yes           Yes           Laboratory Technician
#
#      Attrition     BusinessTravel              Department  Gender  \
# 0          Yes      Travel_Rarely                   Sales  Female
# 1           No  Travel_Frequently  Research & Development    Male
# 2          Yes      Travel_Rarely  Research & Development    Male
# 3           No  Travel_Frequently  Research & Development  Female
# 4           No      Travel_Rarely  Research & Development    Male
# ...        ...                ...                     ...     ...
# 1023        No      Travel_Rarely  Research & Development  Female
# 1024        No      Travel_Rarely  Research & Development  Female
# 1025        No      Travel_Rarely                   Sales  Female
# 1026        No      Travel_Rarely                   Sales    Male
# 1027        No      Travel_Rarely  Research & Development  Female
#
#                     JobRole MaritalStatus OverTime
# 0           Sales Executive        Single      Yes
# 1        Research Scientist       Married       No
# 2     Laboratory Technician        Single      Yes
# 3        Research Scientist       Married      Yes
# 4     Laboratory Technician       Married       No
# ...                     ...           ...      ...
# 1023     Research Scientist       Married       No
# 1024      Research Director       Married       No
# 1025        Sales Executive       Married      Yes
# 1026        Sales Executive       Married       No
# 1027  Laboratory Technician       Married       No
#
# [1028 rows x 13 columns]

# %%
#finding the correlation between the columns
corr=numeric_df.corr()

# %%
sns.heatmap(corr)
plt.show()

# %% [markdown]
# There are high correlation between the columns

# %% [markdown]
# ## Data analysis

# %%
#distribution of targets

# declaring data
data = train_data['Attrition'].value_counts()
ratios = train_data['Attrition'].value_counts().tolist()
keys = ['No','Yes']

# declaring exploding pie
explode = [0, 0.1]
# define Seaborn color palette to use
\ = sns.color_palette('dark')

# plotting data on chart
plt.pie(ratios, labels=keys, colors=palette_color,
        explode=explode, autopct='%.0f%%',textprops={'color':"y"})

# displaying chart
plt.savefig('/content/drive/MyDrive/Results/targets')

plt.show()

# %%
#attrition departmentwise
sns.countplot(data=train_data, x="Department", hue="Attrition")
plt.savefig('/content/drive/MyDrive/Results/department')

plt.show()

# %%
sns.dark_palette("#79C")
sns.countplot(data=train_data, x="Reason for leaving", hue="Attrition",palette=["#fc9272","#fee0d2"])
plt.xticks(rotation=90)
plt.savefig('/content/drive/MyDrive/Results/department')

plt.show()

# %%
#distribution of age
sns.dark_palette("seagreen")
sns.histplot(x=train_data['Age'],color='#8294C4',kde=True)
plt.title('Distribution of employee age')
plt.savefig('/content/drive/MyDrive/Results/age')

# %%
#distribution of age
sns.dark_palette("seagreen")
sns.histplot(x=train_data['MonthlyIncome'],color='#5C8984',kde=True)
plt.title('Distribution of employee Monthly income')
plt.savefig('/content/drive/MyDrive/Results/age')
plt.show()

# %%
sns.boxplot(x=train_data['Attrition'],y=train_data['MonthlyIncome'],palette="Set1")
plt.savefig('/content/drive/MyDrive/Results/income')
plt.show()

# %%
my_colors = ["#9b59b6", "#3498db",
             "#2ecc71", "#006a4e"]
sns.set_palette( my_colors )
sns.violinplot(x=train_data['Gender'],y=train_data['MonthlyIncome'],hue=train_data['Attrition'])
plt.savefig('/content/drive/MyDrive/Results/Business_travel')
plt.show()

# %% [markdown]
# # `Feature selection`

# %% [markdown]
# Removing constant features

# %%
len(train_data.columns)
# Out:
# 29

# %%
#categorical encoding
train_data=train_data.apply(LabelEncoder().fit_transform)
train_data.head()
# Out:
#    Age  NumCompaniesWorked  Previous company experience  \
# 0   23                   1                            1
# 1   31                   2                            1
# 2   19                   1                            1
# 3   15                   1                            1
# 4    9                   1                            1
#
#    Job role in previous company  \
# 0                             2
# 1                             7
# 2                             3
# 3                             7
# 4                             3
#
#    Number of years experience in prevoius company  Reason for leaving  \
# 0                                               8                   1
# 1                                               1                   4
# 2                                               6                   1
# 3                                               1                   1
# 4                                               9                   1
#
#    Salary in previous company  Present expectation Y/N  \
# 0                         573                        1
# 1                         494                        1
# 2                          45                        1
# 3                         231                        1
# 4                         292                        1
#
#    Expectation of hike in %  Promotion Y/N  ...  JobRole  JobSatisfaction  \
# 0                         3              1  ...        7                3
# 1                         3              1  ...        6                1
# 2                         3              1  ...        2                2
# 3                         3              1  ...        6                2
# 4                         3              1  ...        2                1
#
#    MaritalStatus  MonthlyIncome  OverTime  PerformanceRating  \
# 0              2            573         1                  0
# 1              1            494         0                  1
# 2              2             45         1                  0
# 3              1            231         1                  0
# 4              1            292         0                  0
#
#    StockOptionLevel  TotalWorkingYears  YearsAtCompany  YearsWithCurrManager
# 0                 0                  8               5                     5
# 1                 1                 10               9                     7
# 2                 0                  7               4                     0
# 3                 0                  8               7                     0
# 4                 1                  6               1                     2
#
# [5 rows x 29 columns]

# %%
#seperating the features and targets
X_train = train_data.drop(['Attrition'],axis=1)
y_train = train_data['Attrition']

# %%
# using sklearn variancethreshold to find constant features
from sklearn.feature_selection import VarianceThreshold
sel = VarianceThreshold(threshold=0)
sel.fit(X_train)  # fit finds the features with zero variance
# Out:
# VarianceThreshold(threshold=0)

# %%
# get_support is a boolean vector that indicates which features are retained
# if we sum over get_support, we get the number of features that are not constant
sum(sel.get_support())
# Out:
# 28

# %%
# print the constant features
print(
    len([
        x for x in X_train.columns
        if x not in X_train.columns[sel.get_support()]
    ]))

[x for x in X_train.columns if x not in X_train.columns[sel.get_support()]]
# Out:
# 0
# []

# %% [markdown]
# There are no constant features...

# %% [markdown]
# ## Removing quasi constant features

# %%
sel = VarianceThreshold(threshold=0.01)  # 0.1 indicates 99% of observations approximately

sel.fit(X_train)  # fit finds the features with low variance
# Out:
# VarianceThreshold(threshold=0.01)

# %%
# get_support is a boolean vector that indicates which features
# are retained. If we sum over get_support, we get the number
# of features that are not quasi-constant
sum(sel.get_support())
# Out:
# 28

# %%
## finally we can print the quasi-constant features
print(
    len([
        x for x in X_train.columns
        if x not in X_train.columns[sel.get_support()]
    ]))

[x for x in X_train.columns if x not in X_train.columns[sel.get_support()]]
# Out:
# 0
# []

# %% [markdown]
# There are no quasi constant features

# %% [markdown]
# ## Univariate feature selection

# %% [markdown]
# Select K Best

# %%
k = 10
feature_names = train_data.columns
# Create a SelectKBest instance with chi-square score function
selector = SelectKBest(score_func=f_classif, k=k)

# Fit the selector to your data
selector.fit(X_train, y_train)
# Out:
# SelectKBest()

# %%
# Get the scores and corresponding feature indices
scores = selector.scores_
feature_indices = np.arange(len(scores))

# Sort the scores and feature indices in descending order
sorted_indices = np.argsort(scores)[::-1]
sorted_scores = scores[sorted_indices]
sorted_features = feature_indices[sorted_indices]

# Get the top k feature names
top_feature_names = [feature_names[i] for i in sorted_features[:k]]
top_feature_names
# Out:
# ['MonthlyIncome',
#  'MaritalStatus',
#  'Salary in previous company',
#  'StockOptionLevel',
#  'JobSatisfaction',
#  'Previous company experience',
#  'NumCompaniesWorked',
#  'JobInvolvement',
#  'Age',
#  'PerformanceRating']

# %%
features_df_new = train_data[top_feature_names]
features_df_new
# Out:
#       MonthlyIncome  MaritalStatus  Salary in previous company  \
# 0               573              2                         573
# 1               494              1                         494
# 2                45              2                          45
# 3               231              1                         231
# 4               292              1                         292
# ...             ...            ...                         ...
# 1023             36              1                          36
# 1024            897              1                         897
# 1025            359              1                         359
# 1026            728              1                         728
# 1027            272              1                         272
#
#       StockOptionLevel  JobSatisfaction  Previous company experience  \
# 0                    0                3                            1
# 1                    1                1                            1
# 2                    0                2                            1
# 3                    0                2                            1
# 4                    1                1                            1
# ...                ...              ...                          ...
# 1023                 1                0                            1
# 1024                 2                2                            1
# 1025                 2                2                            0
# 1026                 1                3                            1
# 1027                 1                1                            1
#
#       NumCompaniesWorked  JobInvolvement  Age  PerformanceRating
# 0                      1               2   23                  0
# 1                      2               1   31                  1
# 2                      1               1   19                  0
# 3                      1               2   15                  0
# 4                      1               2    9                  0
# ...                  ...             ...  ...                ...
# 1023                   1               2   38                  1
# 1024                   4               2   29                  0
# 1025                   1               2    6                  0
# 1026                   1               2   14                  0
# 1027                   1               1   16                  0
#
# [1028 rows x 10 columns]

# %%
# Plot the scores
plt.figure(figsize=(10, 6))
plt.bar(range(k), sorted_scores[:k])
plt.xticks(range(k), top_feature_names, rotation=45, ha='right')
plt.xlabel('Feature Name')
plt.ylabel('Score')
plt.title('SelectKBest Scores')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Preparation of test data

# %%
#reading the test data
test_data = pd.read_csv('/content/drive/MyDrive/Datasets/Emp_attrition_Test.csv')

# %%
#categorical encoding
test_data = test_data.apply(LabelEncoder().fit_transform)

# %%
#seperating the features and labels
X_test = test_data.drop(['Attrition'],axis=1)
y_test = test_data['Attrition']

# %%
X_test =X_test[top_feature_names]

# %%
X_test.head()
# Out:
#    MonthlyIncome  MaritalStatus  Salary in previous company  StockOptionLevel  \
# 0             24              1                          24                 0
# 1            152              0                         152                 2
# 2            379              0                         379                 1
# 3            366              0                         366                 1
# 4            138              2                         138                 0
#
#    JobSatisfaction  Previous company experience  NumCompaniesWorked  \
# 0                2                            1                   1
# 1                2                            1                   2
# 2                3                            1                   3
# 3                3                            1                   4
# 4                0                            1                   2
#
#    JobInvolvement  Age  PerformanceRating
# 0               3   22                  0
# 1               2   21                  0
# 2               2   12                  0
# 3               2   27                  0
# 4               1   20                  1

# %% [markdown]
# ## Machine learning models

# %%
features_df_new.columns
# Out:
# Index(['MonthlyIncome', 'MaritalStatus', 'Salary in previous company',
#        'StockOptionLevel', 'JobSatisfaction', 'Previous company experience',
#        'NumCompaniesWorked', 'JobInvolvement', 'Age', 'PerformanceRating'],
#       dtype='object')

# %%
k = 5

# Create a logistic regression model (replace with your desired model)

estimator = RandomForestClassifier()
# Create a k-fold cross-validation object
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# Perform cross-validation
scores = cross_val_score(estimator, X_train, y_train, cv=kf, scoring='accuracy')

# Print the accuracy scores for each fold
print('Accuracy scores for each fold:', scores)

# Calculate and print the average accuracy across all folds
average_accuracy = np.mean(scores)
print('Average accuracy:', average_accuracy)
# Out:
# Accuracy scores for each fold: [0.86893204 0.8592233  0.83009709 0.82439024 0.85853659]
# Average accuracy: 0.8482358512905517

# %%
folds = list(range(1, len(scores) + 1))

# Plot the accuracy scores
plt.bar(folds, scores)
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.title('Accuracy Scores for Cross-Validation')
plt.show()

# %% [markdown]
# ## Machine learning models

# %% [markdown]
# Gradient Boosting

# %%
#Gradient boosting classifier
gb = GradientBoostingClassifier()
#fitting the model
gb.fit(features_df_new,y_train)
# Out:
# GradientBoostingClassifier()

# %%
#model testing
gb_preds = gb.predict(X_test)
gb.score(X_test,y_test)
# Out:
# 0.8235294117647058

# %% [markdown]
# Classification report

# %%
print(classification_report(y_test,gb_preds,target_names=['Yes','No']))
# Out:
#               precision    recall  f1-score   support
#
#          Yes       0.87      0.93      0.90       377
#           No       0.35      0.23      0.28        65
#
#     accuracy                           0.82       442
#    macro avg       0.61      0.58      0.59       442
# weighted avg       0.80      0.82      0.81       442

# %% [markdown]
# Confusion matrix

# %%
cm = confusion_matrix(y_test,gb_preds)
sns.heatmap(cm,annot=True,fmt='g',cmap="BuPu")
plt.show()

# %%
y_pred_proba = gb.predict_proba(X_test)[:, 1]

# Calculate the false positive rate, true positive rate, and threshold values
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

# Calculate the AUC
auc = roc_auc_score(y_test, y_pred_proba)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC curve (AUC = {:.2f})'.format(auc))
plt.plot([0, 1], [0, 1], 'k--')  # Plot the random guessing curve
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Ada Boosting

# %%
ada = AdaBoostClassifier()
#fitting the model
ada.fit(features_df_new,y_train)
# Out:
# AdaBoostClassifier()

# %%
#model testing
ada_preds = ada.predict(X_test)
ada.score(X_test,y_test)
# Out:
# 0.8257918552036199

# %% [markdown]
# Classification report

# %%
print(classification_report(y_test,ada_preds,target_names=['Yes','No']))
# Out:
#               precision    recall  f1-score   support
#
#          Yes       0.87      0.94      0.90       377
#           No       0.32      0.17      0.22        65
#
#     accuracy                           0.83       442
#    macro avg       0.60      0.55      0.56       442
# weighted avg       0.79      0.83      0.80       442

# %% [markdown]
# Confusion matrix

# %%
cm = confusion_matrix(y_test,ada_preds)
sns.heatmap(cm,annot=True,fmt='g',cmap="BuPu")
plt.show()

# %%
y_pred_proba = ada.predict_proba(X_test)[:, 1]

# Calculate the false positive rate, true positive rate, and threshold values
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

# Calculate the AUC
auc = roc_auc_score(y_test, y_pred_proba)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC curve (AUC = {:.2f})'.format(auc))
plt.plot([0, 1], [0, 1], 'k--')  # Plot the random guessing curve
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
